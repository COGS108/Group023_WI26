# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# * Alphonse Silver:
# * Jingbo Peng:
# * Ali Yousuf:
# * Fahad Alkhazam:
# * Andrea Melendez:

# %% [markdown]
# # Research Question

# %% [markdown]
# __Do socioeconomic factors outweigh an individuals academic effort in predicting a student's final exam score?__ <br>
#
# We aim to determine whether students from low income backgrounds can compensate for their lower socioeconomic support with high study hours. In general, can a student from a poor family compete academically with a student from a wealthy family through hard work? We will seek to answer this question by performing linear regression and correlation analysis to compare effort-based variables (hours studied, attendance) to family advantages (family income, parental education level, access to resources).

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# There has been an ongoing debate on what factors make a student successful. The American dream tells us that if you work hard enough, you can achieve top grades no matter the background. But according to educational researchers, a student's family background is often a stronger predictor of success than their individual effort.<a name="cite_ref-1"></a><sup>1</sup> Using real world data, we wish to verify if hard work, like studying, can truly compete with advantages like family income. Through data science, we hope to check whether this traditional notion of success through hard work is factual or an unattainable myth.
#
# Being raised in a wealthy family where their parents are highly educated more often than not provides an unequal advantage. Studies show that wealth translates directly into better learning environments and more abundant learning resources.<a name="cite_ref-2"></a><sup>2</sup> This includes minor details such as quiet comfortable places to study, faster and stabler internet, and parents or hired tutors who are readily available to help with their study. As such, wealthier students might study for similar hours compared to a low income student, but yield better grades for the same amount of work and time put in.
#
# Although these advantages appear to be highly relevant to academic success, hard work is often still required in order to succeed. Analysis of real word data on study hours and attendance prove to still be statistically significant.<a name="cite_ref-3"></a><sup>3</sup> This suggests that an individual's choice also plays a large role in success. However, whether hard work can actually close the gap between wealth and family support is the question we are actually curious about. Can a student level their playing field simply by putting in more effort.
#
# We must also examine the role of parents in their children's success. Research consistently proves that the parent's education level is the single largest factor in determining the success of their children.<a name="cite_ref-4"></a><sup>4</sup> Parents who hold degrees know the school system well enough to guide their children through the hurdles of college. This assistance is a significant advantage unrelated to their children's intelligence or work ethic. From comparing background factors like such against the student's own motivation, we can extrapolate the greater factor in attaining a higher final exam score.
#
#
# 1. <a name="cite_note-1"></a> ^ Dave, D. M., et al. (2025). The Effect of Family Income on Children’s Academic Achievement. Cato Institute. Research Briefs in Economic Policy No. 452. https://www.cato.org/research-briefs-economic-policy/effect-family-income-childrens-academic-achievement
#
# 2. <a name="cite_note-2"></a> ^ Rimm-Kaufman, S. E., & Sandilos, L. E. (2016). Parental income and the fruits of labor: Variability in homework efficacy in secondary school. Journal of School Psychology. https://pmc.ncbi.nlm.nih.gov/articles/PMC3659160/
#
# 3. <a name="cite_note-3"></a> ^ Oki, J. (2024). The Effect of Socioeconomic Status on Academic Achievement: A Big Data Study. PLOS ONE. https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0335485
#
# 4. <a name="cite_note-4"></a> ^ Erola, J., Jalonen, S., & Lehti, H. (2016). Parental education, class and income over early life course and children’s achievement. Research in Social Stratification and Mobility. https://www.sciencedirect.com/science/article/pii/S027656241630018X

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We predict that socioeconomic factors: family income and parents' education level will have a stronger correlation with exam scores than individual variables: study hours and attendance. The reasoning behind this is that majority of the research articles found online points to resources as a great factor in amplifying a student's personal efforts. However, we also wish to show that the hard work students of low income family is not futile.

# %% [markdown]
# ## Data

# %% [markdown]
# 1. **Ideal Dataset**
#     1. **Variables**
#         1. **Individual Metrics:** hours studied, motivation, attendance, etc.
#         2. **Socioeconomic Metrics:** wealth, parent educational level, etc.
#         3. **Outcome:** exam scores, gpa, etc.
#     2. **Observations**
#         1. Ideally we aim for over 1,000 observations across a wide area, which includes areas of wealth and poverty.
#     3. **Collection Method**
#         1. We will read the data directing from the URL using pandas.
#     4. **Storage**
#         1. The data will be directly read from the site and can be readily downloaded to the cloud or PC is needed.
#
# 2. **Real Datasets Found**
#     1. **Dataset 1: Student Performance Factors (The chosen dataset)** <br> <br>
#     URL: https://www.kaggle.com/datasets/ayeshasiddiqa123/student-perfirmance
#     This is a dataset from Kaggle with over 6000 samples. It contains all the relevant variables and most importantly, we are able to compare individual effort vs family background with the given variables. The important variables we will use are Hours Studied and Attendance to measure effort, alongside Family Income and Parental Education Level to measure background. The dataset is public and does not need permission. <br>
#     3. **Dataset 2: Student Performance Data Set (University of California Irvine Machine Learning Repository)** <br><br>
#     URL: https://archive.ics.uci.edu/ml/datasets/Student+Performance
#     This is a dataset from the UCI Machine Learning Repository with approximately 1000 samples. It contains all the relevant variables and most importantly, we are able to compare individual effort vs family background with the given variables. The important variables in this file include study time and absences for effort, and parent education and job titles for background context. The dataset is public and does not need permission.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://drive.google.com/uc?export=download&id=10D6ERO0Z64niQauvKP7XlfmTCX-2-ZfI', 'filename':'kaggle_data.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1AKLjVS1Ixys8M33O6-n5eJYIJgS0XdrI', 'filename':'irvine_data.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress:  50%|█████████         | 1/2 [00:01<00:01,  1.34s/it]
# Successfully downloaded: kaggle_data.csv
# ...
# Overall Download Progress: 100%|██████████████████| 2/2 [00:02<00:00,  1.36s/it]
# Successfully downloaded: irvine_data.csv

# %% [markdown]
# ### Dataset #1
#
# Instructions:
# 1. Change the header from Dataset #1 to something more descriptive of the dataset
# 2. Write a few paragraphs about this dataset. Make sure to cover
#    1. Describe the important metrics, what units they are in, and giv some sense of what they mean.  For example "Fasting blood glucose in units of mg glucose per deciliter of blood.  Normal values for healthy individuals range from 70 to 100 mg/dL.  Values 100-125 are prediabetic and values >125mg/dL indicate diabetes. Values <70 indicate hypoglycemia. Fasting idicates the patient hasn't eaten in the last 8 hours.  If blood glucose is >250 or <50 at any time (regardless of the time of last meal) the patient's life may be in immediate danger"
#    2. If there are any major concerns with the dataset, describe them. For example "Dataset is composed of people who are serious enough about eating healthy that they voluntarily downloaded an app dedicated to tracking their eating patterns. This sample is likely biased because of that self-selection. These people own smartphones and may be healthier and may have more disposable income than the average person.  Those who voluntarily log conscientiously and for long amounts of time are also likely even more interested in health than those who download the app and only log a bit before getting tired of it"
# 3. Use the cell below to
#     1. load the dataset
#     2. make the dataset tidy or demonstrate that it was already tidy
#     3. demonstrate the size of the dataset
#     4. find out how much data is missing, where its missing, and if its missing at random or seems to have any systematic relationships in its missingness
#     5. find and flag any outliers or suspicious entries
#     6. clean the data or demonstrate that it was already clean.  You may choose how to deal with missingness (dropna of fillna... how='any' or 'all') and you should justify your choice in some way
#     7. You will load raw data from `data/00-raw/`, you will (optionally) write intermediate stages of your work to `data/01-interim` and you will write the final fully wrangled version of your data to `data/02-processed`
# 4. Optionally you can also show some summary statistics for variables that you think are important to the project
# 5. Feel free to add more cells here if that's helpful for you

# %% [markdown]
# ### Dataset #1: Student Performance Factors (Kaggle)
#
# **Description & Relevance**
# This dataset contains survey results from over 6,000 students with variables on individual effort and background.
# - **Exam_Score**: The target variable, representing the student's final grade (0-100).
# - **Hours_Studied**: Number of hours studied per week
# - **Attendance**: A percentage or count representing class attendance (higher is better).
# - **Family_Income**: (Low, Medium, High) representing the socioeconomic status of the student's family.
# - **Parental_Education_Level**: (High School, College) indicating the highest education level of the parents.
# - **Access_to_Resources**: (Low, Medium, High) indicating access to educational materials and internet.
#
# **Potential Issues & Bias**
# The data comes from a survey by the students themselves, therefore there is the possibility that variables such as income or study hours may have response bias. Also, the data does not describe where or what type of schools (private or public) the survey was performed and the quality of the surveyed schools, so there may be additional biases.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Loading first set of data
df_1 = pd.read_csv('data/00-raw/kaggle_data.csv')

print(f"Row x Columns: {df_1.shape}")

# Checking for Missing Data
print(f"Missing Values per Column: {df_1.isnull().sum()}")
df_1.head(5)
# Out:
# Row x Columns: (6607, 20)
# Missing Values per Column: Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# ...

# %% [markdown]
# **Data contains 6607 samples, with missing data in Teacher_Quality, Physical_Activity, Parental Education**

# %% [markdown]
# #### Missing Data Analysis
# - Parental_Education_Level is the only relevant variable with missing data to our research question, therefore we will check for correlation between missing data and Exam_Score to assure there is not systematic relationship with missingness.
# - Other rows with missing values will be dropped, as the data is large enough compared to missing values (<5%) and the variables are not relevant to our research question.

# %%
# Checking for systematic missingness 
df_1['missing_parent_ed'] = df_1['Parental_Education_Level'].isnull().astype(int)

# Find correlation between Parental_Education_Level and Exam_Score
corr_val = df_1['missing_parent_ed'].corr(df_1['Exam_Score'])
print(f"Correlation of Missing Parental_Education_Level vs Exam_Score: {corr_val:.2f}")

if abs(corr_val) < 0.05: 
    print("Result: Correlation below threshold of 0.05.")
    print("Conclusion: Negligible correlation, so the data is safe to drop.")
else:
    print("Result: Correlation above threshold of 0.05.")
    print("Conclusion: Significant correlation, so the data should be preserved.")

df_1 = df_1.drop(columns=['missing_parent_ed'])
# Out:
# Correlation of Missing Parental_Education_Level vs Exam_Score: -0.01
# Result: Correlation below threshold of 0.05.
# Conclusion: Negligible correlation, so the data is safe to drop.

# %% [markdown]
# **Test Results:** We checked with point-biserial correlation coefficient to determine that the data points regarding Parental_Education_Level were not missing completely at random, so the data is irrelevant to the student's ability, and is safe to drop.

# %%
# Remove rows with missing values
df_1_clean = df_1.dropna().copy()

# Check for duplicate entries
duplicates = df_1_clean.duplicated().sum()

assert duplicates == 0, "Contains Duplicates"

# Plot boxplot to visualize data in case of impossible values
plt.figure(figsize = (8, 4))
sns.boxplot(x=df_1_clean['Exam_Score'])
plt.title('Exam Score Boxplot')
plt.show()

# %% [markdown]
# **Results**: Boxplot appears to only contain possible scores (0-100). The extra data points above 100 appears to suggest there is extra credit. We will proceed with this data.

# %%
# Removing irrelevant variables and mapping strings of categorical vars to ints
cols_to_drop = ['Distance_from_Home', 'Physical_Activity', 'Peer_Influence', 
                'Sleep_Hours','Parental_Involvement', 'Learning_Disabilities', 
                'Previous_Scores', 'Gender', 'Extracurricular_Activities']

education_map = {
    'High School': 1,
    'College': 2,
    'Postgraduate': 3
}

intensity_map = {
    'Low': 1,
    'Medium': 2,
    'High': 3
}

binary_map = {
    'Yes': 1,
    'No': 0
}

school_map = {
    'Public': 0,
    'Private': 1
}

df_1_clean['Parental_Education_Level'] = df_1_clean['Parental_Education_Level'].map(education_map)

intensity_cols = ['Access_to_Resources', 'Motivation_Level', 'Family_Income', 'Teacher_Quality']
for col in intensity_cols:
    if col in df_1_clean.columns:
        df_1_clean[col] = df_1_clean[col].map(intensity_map)

df_1_clean['Internet_Access'] = df_1_clean['Internet_Access'].map(binary_map)
df_1_clean['School_Type'] = df_1_clean['School_Type'].map(school_map)

df_1_clean = df_1_clean.drop(columns=cols_to_drop)

# Saving Data to data/02-processed
df_1_clean.to_csv('data/02-processed/kaggle_dataset_cleaned.csv', index=False)

# %% [markdown]
# ### Dataset #2: Student Performance (UCI)
#
# **Description & Relevance**
# This dataset comes from the UCI Machine Learning Repository and collects data from two Portuguese schools. It focuses on student achievement in secondary education. Unlike the Kaggle dataset, this data is well-documented academic research.
# - **G3 (Final Grade)**: The target variable. This is numeric on a scale of 0 to 20. We may need to normalize this to 0-100 to compare it with the Kaggle dataset.
# - **Medu / Fedu**: Mother's and Father's education level (0=none, 1=primary, 2=5th-9th grade, 3=secondary, 4=higher education). This directly addresses our need for parental education.
# - **studytime**: Weekly study time (ordinal: 1=<2 hours, 2=2-5 hours, 3=5-10 hours, 4=>10 hours).
# - **absences**: Number of school absences (0 to 93).
# - **famrel**: Quality of family relationships (1=very bad to 5=excellent).
#
# **Potential Issues & Bias**
# The largest issue with this set of data is that the data comes from schools in Portugal, which introduces geological and cultural bias. The grading scale ranges between 0-20 which is different from the US's 0-100 scale. The studytime variable is categorized into multiple ranges of hours rather than a raw count of hours, so comparison with data from Kaggle can be flawed.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
# Loading second set of data
df_2 = pd.read_csv('data/00-raw/irvine_data.csv', sep=';')

print(f"Row x Columns: {df_2.shape}")

# Dropping columns unrelated to research question
columns_to_drop = [
    'school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 
    'reason', 'guardian', 'traveltime', 'failures', 'activities', 
    'nursery', 'higher', 'romantic', 'famrel', 'freetime', 
    'goout', 'Dalc', 'Walc', 'health', 'G1', 'G2'
]

df_2_relevant = df_2.drop(columns=columns_to_drop, errors='ignore').rename(columns={'G3': 'Exam_Score'})

# Checking for Missing Data
print(f"Missing Values per Column: {df_2_relevant.isnull().sum()}")
df_2_relevant.head(5)

mapping = {'yes': 1, 'no': 0}
cols_to_fix = ['schoolsup', 'famsup', 'paid', 'internet']
for col in cols_to_fix:
    if col in df_2_relevant.columns:
        df_2_relevant[col] = df_2_relevant[col].map(mapping)
# Out:
# Row x Columns: (395, 33)
# Missing Values per Column: Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# studytime     0
# schoolsup     0
# famsup        0
# paid          0
# internet      0
# absences      0
# Exam_Score    0
# dtype: int64

# %% [markdown]
# **Data contains 395 entries and does not contain missing values, so missing values analysis cannot be performed**

# %%
duplicates = df_2_relevant.duplicated().sum()

assert duplicates == 0, "Contains Duplicates"

# %% [markdown]
# **Data does not contain duplicate rows**

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=df_2_relevant['Exam_Score'])
plt.title('Boxplot of Exam Scores (Range 0-20)')
plt.show()

# %% [markdown]
# **Results:** There are scores of 0 on the exam, which indicates that there is a possibility these indicates no-shows, which may skew our research results. There are no impossible values outside the possible ranges (0-20).

# %%
# Counting number of 0's in Exam_Score
zero_count = len(df_2_relevant[df_2_relevant['Exam_Score']==0])
print(f"Number of scores of 0: {zero_count}")
# Out:
# Number of scores of 0: 38

# %% [markdown]
# **Results:** The 0's for exam scores can largely be interpreted as students who did not show up for the exam. These data points can be regarded as empty and should be dropped. Keeping them can likely introduce systematic error. But since we assumed these data to be missing, we will perform analysis to identify if there is systematic relationship between missingness of this variable to Exam_Score.

# %% [markdown]
# #### Missing Analysis
# - We will check for correlation with the relevant variables Medu, Fedu, studytime, and absences, since we cannot correlate 0 exam score with Exam_Score itself.

# %%
df_2_relevant['is_zero_score'] = (df_2_relevant['Exam_Score'] == 0).astype(int)

relevant_columns = ['Medu', 'Fedu', 'studytime', 'absences']
corr_val = df_2_relevant[relevant_columns + ['is_zero_score']].corr()['is_zero_score']
print(corr_val)

# Dropping samples with exam scores of 0
df_2_clean = df_2_relevant[df_2_relevant['Exam_Score'] > 0]
df_2_clean = df_2_clean.drop(columns=['is_zero_score'])

#Normalization
df_2_clean['Exam_Score_100'] = df_2_clean['Exam_Score'] * 5
df_2_clean['Exam_Score'] = df_2_clean['Exam_Score_100']
df_2_clean = df_2_clean.drop(columns=['Exam_Score_100'])

df_2_clean.to_csv('data/02-processed/irvine_dataset_cleaned.csv', index=False)
df_2_clean.head(5)
# Out:
# Medu            -0.129380
# Fedu            -0.069658
# studytime       -0.024039
# absences        -0.233023
# is_zero_score    1.000000
# Name: is_zero_score, dtype: float64
#    Medu  Fedu     Mjob      Fjob  studytime  schoolsup  famsup  paid  \
# 0     4     4  at_home   teacher          2          1       0     0
# 1     1     1  at_home     other          2          0       1     0
# 2     1     1  at_home     other          2          1       0     1
# 3     4     2   health  services          3          0       1     1
# 4     3     3    other     other          2          0       1     1
#
#    internet  absences  Exam_Score
# 0         0         6          30
# 1         1         4          30
# 2         1        10          50
# 3         1         2          75
# 4         0         4          50

# %% [markdown]
# **Results:** By analyzing the correlations of students with a score of 0 on their exam and the key variables, we determined there is negligible correlation with study time (-2%). We observed weak correlation with mother's education (-13%) and father's education (-7%). There is a moderate correlation with absenses (~23%).
#
# **Conclusion:** We determined that the missing data is not completely random. However, we choose to exclude these entries (~10% of data), since the score of 0 more so represents a lack of data instead of a valid metric. There may be bias introduced as a result of removing these data points with lower maternal and paternal education, but we believe that our linear regression would be more accurate without than with these data points.

# %% [markdown]
# ### Exploratory Data Analysis
#
# In this section, we explore the processed student performance dataset to better understand the relationships between socioeconomic background, academic effort, and exam performance. The goal of this exploratory analysis is to identify patterns, distributions, and relationships among variables before conducting deeper analysis.
#
# We examine the distribution of exam scores, the relationship between study effort and exam performance, and how socioeconomic factors such as parental education relate to student outcomes. Visualizations such as histograms, scatter plots, boxplots, and correlation heatmaps are used to better understand the structure of the data and identify potential trends relevant to our research question.

# %% [markdown]
# #### Distribution of Exam Scores

# %% [markdown]
# Before analyzing relationships between variables, we first examine the distribution of the outcome variable: **Exam_Score**. Understanding the distribution helps identify patterns such as skewness, clustering of scores, or potential outliers.
#
# A histogram allows us to visualize how exam scores are distributed across students. This helps determine whether scores are normally distributed, concentrated in certain ranges, or affected by extreme values.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_2_relevant['Exam_Score'], bins=15, kde=True)

plt.title("Distribution of Exam Scores")
plt.xlabel("Exam Score")
plt.ylabel("Number of Students")

plt.show()

# %% [markdown]
# **Interpretation**
#
# The histogram shows how exam scores are distributed among students. If the distribution appears roughly normal, this suggests most students perform around the average score, with fewer students performing extremely poorly or extremely well.
#
# Understanding this distribution is important because it helps determine whether exam performance varies widely among students or tends to cluster around a central value.

# %% [markdown]
# #### Relationship Between Study Effort and Exam Score

# %% [markdown]
# Next, we explore how **academic effort** relates to exam performance. In this dataset, study effort is represented by the variable **studytime**, which measures how much time students dedicate to studying.
#
# A scatter plot helps visualize whether higher study time corresponds to higher exam scores. If effort strongly influences performance, we would expect to see a positive trend between study time and exam score.

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x=df_2_relevant['studytime'],
    y=df_2_relevant['Exam_Score']
)

plt.title("Study Time vs Exam Score")
plt.xlabel("Study Time")
plt.ylabel("Exam Score")

plt.show()

# %% [markdown]
# **Interpretation**
#
# This scatter plot allows us to observe whether students who spend more time studying tend to achieve higher exam scores. A positive relationship would suggest that academic effort plays a significant role in exam performance. If the points appear widely scattered without a clear upward trend, it may indicate that study time alone does not strongly determine exam outcomes.

# %% [markdown]
# #### Socioeconomic Factors and Exam Performance

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x=df_2_relevant['Medu'],
    y=df_2_relevant['Exam_Score']
)

plt.title("Mother's Education Level vs Exam Score")
plt.xlabel("Mother Education Level")
plt.ylabel("Exam Score")

plt.show()

# %% [markdown]
# This boxplot shows how exam scores vary across different levels of parental education. If students with more educated parents tend to have higher exam scores, it may suggest that socioeconomic background plays a role in academic outcomes.

# %% [markdown]
# #### Correlation Between Variables

# %% [markdown]
# To better understand how different variables relate to one another, we compute a **correlation matrix**. Correlation measures the strength and direction of the relationship between two variables.
#
# Values range from **-1 to 1**:
# - **1** = strong positive relationship
# - **0** = no relationship
# - **-1** = strong negative relationship
#
# A heatmap visualization helps identify which variables are most strongly associated with **Exam_Score**. This allows us to quickly see whether effort-related variables or socioeconomic variables appear to have stronger relationships with student performance.

# %%
# select only numeric variables
numeric_df = df_2_relevant.select_dtypes(include=['number'])

# compute correlation matrix
corr_matrix = numeric_df.corr()

plt.figure(figsize=(10,8))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt=".2f"
)

plt.title("Correlation Matrix of Student Performance Variables")

plt.show()

# %% [markdown]
# **Interpretation**
#
# The heatmap displays the correlation coefficients between all numeric variables in the dataset. Darker colors indicate stronger relationships.
#
# By focusing on the column corresponding to **Exam_Score**, we can identify which variables have the strongest positive or negative associations with student performance.
#
# Variables related to **academic effort** (such as study time) may show positive correlations with exam scores, while socioeconomic indicators may also display relationships depending on family background or resources. These correlations help guide further analysis by identifying which predictors may be most important when explaining student performance.

# %% [markdown]
# #### Summary of Exploratory Findings
#
# The exploratory analysis provides an initial understanding of how different factors relate to student exam performance. The distribution of exam scores shows that most students fall within a moderate score range, with fewer students achieving extremely high or low results.
#
# When examining academic effort, study time shows only a weak positive relationship with exam scores, suggesting that while effort may contribute to better performance, it may not be the sole determinant of outcomes. Similarly, socioeconomic indicators such as parental education levels display small positive relationships with exam performance, indicating that family background may also play a role.
#
# The correlation heatmap further supports these observations, as most variables exhibit relatively weak correlations with exam scores. This suggests that student performance is likely influenced by multiple interacting factors rather than a single dominant predictor. These exploratory results help guide further analysis into how both individual effort and socioeconomic context contribute to academic outcomes.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > The data is from Kaggle, so it is a public data with informed consent. However, we cannot rule out that the students have a clear understanding of what the data is used for and nor do we know if their parents know of them answering the survey. The plus side is that the data are anonymous.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > The data might have bias if the students are from a specific area where there is no wealth disparity. Students are also more likely to exaggerate in reporting their hours studied and family wealth.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > The datasets chosen do not contain names or student IDs. We will be careful not to combine specific variables like exact age and job title that could reveal who someone is.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > We are trying to expose the bias in education by using socioeconomic variables such as income and parental education instead of hiding it. We wish to differentiate the effects of wealth from personal effort, so hiding the data on these groups will produce an untruthful result.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > We are keeping the data on datahub and a shared Google Drive that only our group can access. There is no need to protect the data, since it is public on the internet.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > There should be no worries regarding personal information, as all the data are anonymous.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > There is no schedule to delete the data as it is from a public domain (Kaggle), so the risks concerning ethics are minimal to none.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > Students with less attendance may have responsibilities like jobs or caring for family that cannot be seen from the data.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > We checked the data for imbalance. If the dataset has too many wealthy students compared to low income students it could skew our results. We will check the counts of each group before analyzing.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > Our graphs will use clear labels and standard scales to show the truth. We will not crop the y axis to make differences look bigger than they actually are.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > The data is anonymous and contains no trace of information that may be used to be linked to any specific individual.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > Yes, the project is public on Github and every step of the project is documented on a Jupyter Notebook that is being uploaded as changes are made. The results are reproducible, since anyone can download and run the file for the same results.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > We are looking at income and parent education so we must be careful. We do not want to build a model that penalizes students for being poor. We use these variables to understand the gap not to judge students.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > We will check for error rates between wealthy and low income students and truthfully report if whether the model is accurate or not.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We are considering using r-squared and p-value test to determine the strength of the relationship to more accurately and precisely answer the question of how much effort matters in predicitng a student's grade.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > We are using simple linear regression instead of complex machine learning. This allows us to explain exactly how much each variable affects the score in plain English.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We will clearly state in our conclusion that this model only shows correlation and not causation. We will explain that our data is limited to these specific students and might not apply to everyone.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# > This model will not be used for any real world applications, but we will review the final report to ensure that our conclusions are backed by data.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# > If any users are harmed, we can specifically address and correct any statements and claims made through Github.
#
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
# > We are ready to revert changes or pull off the model from Github if necessary.
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > People may reinterpret our findings to assume that only effort matters in determining exam scores, but we will state in our conclusion that effort cannot always overcome wealth barriers.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# 1. **Communication:** We’re using a Discord server for everything—chatting, sharing links, and hopping on voice calls. We expect everyone to check Discord at least once a day so nobody misses an update.
# 2. **Meetings:** We will meet **in person** every **Wednesday at 5 PM** (likely at Geisel Library or Price Center) to work together and check progress before the big Friday deadlines. If someone can't make it to campus, they can join via Discord voice chat.
# 3. **Workload:** We’re splitting things as evenly as possible. If someone is swamped with other midterms or gets stuck on a coding bug, they need to speak up in the chat at least 2 days before the deadline so the rest of us can jump in to help.
# 4. **Decision Making:** For big choices (like changing our dataset), we’ll take a vote. For specific details (like which graph color to use), the person in charge of that section (e.g., the EDA lead) gets the final say.
# 5. **Handling Conflict:** If we disagree, we’ll talk it out in person or on a call instead of arguing over text. If someone completely ghosts the group or isn’t doing their part, we’ll try to reach out to them first. If that doesn't work, we’ll contact the TA/Professor as a last resort.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date | Meeting Time | Completed Before Meeting | Discuss at Meeting |
# |---|---|---|---|
# | 1/20 | 1 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 1/26 | 10 AM | Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 2/1 | 10 AM | Edit, finalize, and submit proposal; Search for datasets | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part |
# | 2/14 | 6 PM | Import & Wrangle Data (Alphonse); EDA (Jingbo) | Review/Edit wrangling/EDA; Discuss Analysis Plan |
# | 2/23 | 12 PM | Finalize wrangling/EDA; Begin Analysis (Ali; Fahad) | Discuss/edit Analysis; Complete project check-in |
# | 3/13 | 12 PM | Complete analysis; Draft results/conclusion/discussion (Andrea) | Discuss/edit full project |
# | 3/20 | Before 11:59 PM | NA | Turn in Final Project & Group Project Surveys |
